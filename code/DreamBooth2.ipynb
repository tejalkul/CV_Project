# %%
from google.colab import drive
drive.mount('/content/drive')
DRIVE_PATH = '/content/drive/MyDrive/dreambooth'
# !mkdir -p '{DRIVE_PATH}'
# Out:
# Mounted at /content/drive

# %%
# %cd '{DRIVE_PATH}'
# !rm -rf diffusers
# !git clone https://github.com/huggingface/diffusers
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# Cloning into 'diffusers'...
# remote: Enumerating objects: 90890, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 90890 (delta 0), reused 3 (delta 0), pack-reused 90882 (from 1)
# Receiving objects: 100% (90890/90890), 66.22 MiB | 15.31 MiB/s, done.
# Resolving deltas: 100% (66942/66942), done.
# Updating files: 100% (1983/1983), done.
# /content/drive/MyDrive/dreambooth

# %%
# %cd '{DRIVE_PATH}'
# %cd diffusers
# !pip install .
# %cd examples/dreambooth
# !pip install -r requirements.txt
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# /content/drive/MyDrive/dreambooth/diffusers
# Processing /content/drive/MyDrive/dreambooth/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (8.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (0.30.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (11.2.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.13.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->diffusers==0.34.0.dev0) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (2025.1.31)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.34.0.dev0-py3-none-any.whl size=3602841 sha256=81440efc8294e8d979698fdf75feb63398a803a754f30902ab3b597ecddfd3e7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1uddl6m1/wheels/23/c6/82/6c9aa22451cbda3ce2e472f7cef848f4d4a5d08d21f10bf910
# Successfully built diffusers
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.33.1
#     Uninstalling diffusers-0.33.1:
#       Successfully uninstalled diffusers-0.33.1
# Successfully installed diffusers-0.34.0.dev0
# /content/drive/MyDrive/dreambooth/diffusers/examples/dreambooth
# Requirement already satisfied: accelerate>=0.16.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (4.51.3)
# Collecting ftfy (from -r requirements.txt (line 4))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.1.6)
# Collecting peft==0.7.0 (from -r requirements.txt (line 7))
#   Downloading peft-0.7.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r requirements.txt (line 7)) (0.30.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->-r requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.7.0->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->-r requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 3)) (2025.1.31)
# Downloading peft-0.7.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 7.3 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: ftfy, peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.15.2
#     Uninstalling peft-0.15.2:
#       Successfully uninstalled peft-0.15.2
# Successfully installed ftfy-6.3.1 peft-0.7.0
# /content/drive/MyDrive/dreambooth

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
#@title Importing training images
import os

# %cd '{DRIVE_PATH}'
# !rm -rf training_images
# !mkdir -p training_images
# %cd training_images
# !git init
# !git pull https://github.com/google/dreambooth.git
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# /content/drive/MyDrive/dreambooth/training_images
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/dreambooth/training_images/.git/
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 5), reused 1 (delta 1), pack-reused 206 (from 1)
# Receiving objects: 100% (212/212), 106.84 MiB | 21.92 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# From https://github.com/google/dreambooth
#  * branch            HEAD       -> FETCH_HEAD
# Updating files: 100% (164/164), done.
# /content/drive/MyDrive/dreambooth

# %%
#@title Training
# %cd '{DRIVE_PATH}'
import re
import os

# !rm -rf output_model
# !mkdir -p output_model
# !rm -rf class_images
# !mkdir -p class_images

dirs = ["grey_sloth_plushie","red_cartoon","pink_sunglasses","shiny_sneaker","backpack_dog"]
for dir_name in dirs:
  source_folder_path = os.path.join("./training_images/dataset", dir_name)
  class_name = re.sub(r'[0-9]','',dir_name).replace("_"," ")

  MODEL_NAME="CompVis/stable-diffusion-v1-4"
  INSTANCE_DIR=source_folder_path
  OUTPUT_DIR=f"./output_model/{dir_name}"
  CLASS_DIR=f"./class_images/{dir_name}"

  print(f"--------------------Training {dir_name}--------------------")

  # !accelerate launch diffusers/examples/dreambooth/train_dreambooth.py \
    --pretrained_model_name_or_path="{MODEL_NAME}"  \
    --instance_data_dir="{INSTANCE_DIR}" \
    --output_dir="{OUTPUT_DIR}" \
    --class_data_dir="{CLASS_DIR}" \
    --with_prior_preservation --prior_loss_weight=1.0 \
    --instance_prompt="a photo of sks {class_name}" \
    --class_prompt="a photo of {class_name}" \
    --resolution=512 \
    --train_batch_size=1 \
    --gradient_accumulation_steps=1 \
    --use_8bit_adam \
    --learning_rate=2e-6 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --num_class_images=10 \
    --max_train_steps=100
# Out:
# /content/drive/MyDrive/dreambooth
# --------------------Training grey_sloth_plushie--------------------
# 2025-04-30 14:03:43.886577: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746021823.906840    4492 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746021823.912857    4492 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 14:03:43.936679: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 04/30/2025 14:03:49 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# model_index.json: 100% 541/541 [00:00<00:00, 3.89MB/s]
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 04/30/2025 14:03:50 - WARNING - huggingface_hub.file_download - Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
#
# scheduler_config-checkpoint.json: 100% 209/209 [00:00<00:00, 1.50MB/s]
#
# config.json: 100% 592/592 [00:00<00:00, 5.15MB/s]
#
# merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 7.55MB/s]
#
#
# preprocessor_config.json: 100% 342/342 [00:00<00:00, 2.92MB/s]
# Fetching 14 files:   7% 1/14 [00:00<00:02,  4.69it/s]
#
# scheduler_config.json: 100% 313/313 [00:00<00:00, 2.82MB/s]
#
#
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.67MB/s]
#
#
# model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 04/30/2025 14:03:50 - WARNING - huggingface_hub.file_download - Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
#
#
#
# config.json: 100% 743/743 [00:00<00:00, 5.07MB/s]
#
#
#
# vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# config.json: 100% 551/551 [00:00<00:00, 2.66MB/s]
#
# merges.txt: 100% 525k/525k [00:00<00:00, 2.36MB/s]
#
#
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 12.7MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 04/30/2025 14:03:50 - WARNING - huggingface_hub.file_download - Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# model.safetensors:  11% 52.4M/492M [00:00<00:02, 216MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:05, 61.9MB/s]
#
# model.safetensors:  17% 83.9M/492M [00:00<00:01, 212MB/s]
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:03, 96.1MB/s]
# diffusion_pytorch_model.safetensors:  13% 41.9M/335M [00:00<00:03, 88.4MB/s]
#
# model.safetensors:  23% 115M/492M [00:00<00:02, 151MB/s]
#
# model.safetensors:  28% 136M/492M [00:00<00:02, 148MB/s]
# diffusion_pytorch_model.safetensors:  19% 62.9M/335M [00:00<00:02, 102MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.44G [00:00<03:06, 18.3MB/s]
#
# model.safetensors:  32% 157M/492M [00:01<00:02, 143MB/s]
# diffusion_pytorch_model.safetensors:  25% 83.9M/335M [00:00<00:02, 111MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/3.44G [00:00<02:00, 28.3MB/s]
#
# model.safetensors:  36% 178M/492M [00:01<00:02, 127MB/s]
# diffusion_pytorch_model.safetensors:  31% 105M/335M [00:01<00:02, 104MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 31.5M/3.44G [00:00<01:27, 38.8MB/s]
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:01<00:02, 104MB/s]
#
# model.safetensors:  40% 199M/492M [00:01<00:02, 131MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/3.44G [00:01<01:07, 50.3MB/s]
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:01, 108MB/s]
#
# model.safetensors:  45% 220M/492M [00:01<00:02, 125MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 62.9M/3.44G [00:01<00:47, 71.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 73.4M/3.44G [00:01<00:43, 77.7MB/s]
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 106MB/s]
#
# model.safetensors:  49% 241M/492M [00:01<00:02, 110MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 83.9M/3.44G [00:01<00:47, 70.7MB/s]
#
# model.safetensors:  53% 262M/492M [00:02<00:02, 104MB/s]
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:01<00:01, 90.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.44G [00:01<00:49, 67.8MB/s]
# diffusion_pytorch_model.safetensors:  56% 189M/335M [00:02<00:01, 78.6MB/s]
#
# model.safetensors:  58% 283M/492M [00:02<00:02, 97.4MB/s]
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:02<00:01, 78.2MB/s]
#
# model.safetensors:  60% 294M/492M [00:02<00:02, 93.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 126M/3.44G [00:02<00:44, 74.0MB/s]
# diffusion_pytorch_model.safetensors:  63% 210M/335M [00:02<00:01, 80.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 136M/3.44G [00:02<00:42, 78.2MB/s]
#
# model.safetensors:  64% 315M/492M [00:02<00:01, 103MB/s]
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:02<00:01, 83.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 147M/3.44G [00:02<00:43, 76.1MB/s]
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:02<00:01, 87.4MB/s]
#
# model.safetensors:  68% 336M/492M [00:02<00:01, 105MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 157M/3.44G [00:02<00:41, 78.3MB/s]
# diffusion_pytorch_model.safetensors:  75% 252M/335M [00:02<00:00, 99.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 168M/3.44G [00:02<00:41, 78.5MB/s]
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:02<00:00, 88.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 178M/3.44G [00:02<00:39, 82.5MB/s]
#
# model.safetensors:  72% 357M/492M [00:03<00:01, 86.5MB/s]
# diffusion_pytorch_model.safetensors:  81% 273M/335M [00:02<00:00, 87.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 189M/3.44G [00:02<00:38, 84.4MB/s]
#
# model.safetensors:  75% 367M/492M [00:03<00:01, 88.8MB/s]
#
# model.safetensors:  77% 377M/492M [00:03<00:01, 91.7MB/s]
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:03<00:00, 87.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 199M/3.44G [00:02<00:37, 85.9MB/s]
#
# model.safetensors:  79% 388M/492M [00:03<00:01, 93.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 210M/3.44G [00:03<00:35, 90.6MB/s]
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:03<00:00, 94.7MB/s]
#
# model.safetensors:  81% 398M/492M [00:03<00:00, 95.3MB/s]
# diffusion_pytorch_model.safetensors:  94% 315M/335M [00:03<00:00, 94.5MB/s]
#
# model.safetensors:  83% 409M/492M [00:03<00:00, 95.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 231M/3.44G [00:03<00:33, 94.9MB/s]
#
# model.safetensors:  85% 419M/492M [00:03<00:00, 96.3MB/s]
# diffusion_pytorch_model.safetensors:  97% 325M/335M [00:03<00:00, 93.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 241M/3.44G [00:03<00:33, 94.9MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:03<00:00, 91.7MB/s]
#
#
# model.safetensors:  89% 440M/492M [00:03<00:00, 103MB/s]
#
#
# diffusion_pytorch_model.safetensors:   8% 262M/3.44G [00:03<00:32, 98.6MB/s]
#
# model.safetensors:  94% 461M/492M [00:04<00:00, 120MB/s]
#
#
# diffusion_pytorch_model.safetensors:   8% 283M/3.44G [00:03<00:30, 104MB/s]
#
# model.safetensors:  98% 482M/492M [00:04<00:00, 117MB/s]
#
#
# model.safetensors: 100% 492M/492M [00:04<00:00, 112MB/s]
# Fetching 14 files:  43% 6/14 [00:04<00:06,  1.24it/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 304M/3.44G [00:04<00:34, 90.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 325M/3.44G [00:04<00:31, 97.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 336M/3.44G [00:04<00:31, 98.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 357M/3.44G [00:04<00:28, 108MB/s]
#
#
# diffusion_pytorch_model.safetensors:  11% 377M/3.44G [00:04<00:24, 124MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 398M/3.44G [00:04<00:21, 142MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.44G [00:04<00:19, 153MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 440M/3.44G [00:04<00:18, 166MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 461M/3.44G [00:05<00:17, 173MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 482M/3.44G [00:05<00:16, 177MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 503M/3.44G [00:05<00:16, 181MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 524M/3.44G [00:05<00:15, 189MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 545M/3.44G [00:05<00:15, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 566M/3.44G [00:05<00:15, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 587M/3.44G [00:05<00:15, 189MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 608M/3.44G [00:05<00:15, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 629M/3.44G [00:05<00:14, 190MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 661M/3.44G [00:06<00:13, 202MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 692M/3.44G [00:06<00:13, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 713M/3.44G [00:06<00:13, 199MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 734M/3.44G [00:06<00:14, 193MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 755M/3.44G [00:06<00:13, 197MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 776M/3.44G [00:06<00:13, 193MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 797M/3.44G [00:06<00:13, 193MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 828M/3.44G [00:06<00:13, 195MB/s]
#
#
# diffusion_pytorch_model.safetensors:  25% 860M/3.44G [00:07<00:12, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 891M/3.44G [00:07<00:12, 211MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 923M/3.44G [00:07<00:12, 203MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 954M/3.44G [00:07<00:11, 210MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 986M/3.44G [00:07<00:11, 215MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 1.02G/3.44G [00:07<00:11, 218MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 1.05G/3.44G [00:08<00:12, 196MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 1.07G/3.44G [00:08<00:12, 192MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 1.09G/3.44G [00:08<00:12, 192MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.44G [00:08<00:12, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 1.13G/3.44G [00:08<00:13, 176MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 1.15G/3.44G [00:08<00:12, 177MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 1.17G/3.44G [00:08<00:12, 184MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 1.20G/3.44G [00:08<00:12, 180MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 1.22G/3.44G [00:08<00:12, 180MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 1.24G/3.44G [00:09<00:11, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  37% 1.27G/3.44G [00:09<00:10, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.29G/3.44G [00:09<00:10, 197MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.31G/3.44G [00:09<00:10, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  39% 1.34G/3.44G [00:09<00:10, 202MB/s]
#
#
# diffusion_pytorch_model.safetensors:  40% 1.37G/3.44G [00:09<00:10, 200MB/s]
#
#
# diffusion_pytorch_model.safetensors:  41% 1.41G/3.44G [00:09<00:09, 208MB/s]
#
#
# diffusion_pytorch_model.safetensors:  42% 1.44G/3.44G [00:10<00:09, 208MB/s]
#
#
# diffusion_pytorch_model.safetensors:  42% 1.46G/3.44G [00:10<00:09, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  43% 1.48G/3.44G [00:10<00:10, 188MB/s]
#
#
# diffusion_pytorch_model.safetensors:  44% 1.50G/3.44G [00:10<00:10, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  44% 1.52G/3.44G [00:10<00:10, 189MB/s]
#
#
# diffusion_pytorch_model.safetensors:  45% 1.54G/3.44G [00:10<00:10, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  46% 1.57G/3.44G [00:10<00:09, 196MB/s]
#
#
# diffusion_pytorch_model.safetensors:  47% 1.60G/3.44G [00:10<00:08, 205MB/s]
#
#
# diffusion_pytorch_model.safetensors:  48% 1.64G/3.44G [00:11<00:08, 210MB/s]
#
#
# diffusion_pytorch_model.safetensors:  48% 1.67G/3.44G [00:11<00:08, 208MB/s]
#
#
# diffusion_pytorch_model.safetensors:  49% 1.69G/3.44G [00:11<00:09, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  50% 1.71G/3.44G [00:11<00:09, 184MB/s]
#
#
# diffusion_pytorch_model.safetensors:  50% 1.73G/3.44G [00:11<00:09, 180MB/s]
#
#
# diffusion_pytorch_model.safetensors:  51% 1.75G/3.44G [00:11<00:09, 181MB/s]
#
#
# diffusion_pytorch_model.safetensors:  52% 1.77G/3.44G [00:11<00:08, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  52% 1.79G/3.44G [00:11<00:08, 190MB/s]
#
#
# diffusion_pytorch_model.safetensors:  53% 1.81G/3.44G [00:12<00:08, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  54% 1.85G/3.44G [00:12<00:08, 199MB/s]
#
#
# diffusion_pytorch_model.safetensors:  54% 1.87G/3.44G [00:12<00:07, 201MB/s]
#
#
# diffusion_pytorch_model.safetensors:  55% 1.90G/3.44G [00:12<00:07, 207MB/s]
#
#
# diffusion_pytorch_model.safetensors:  56% 1.92G/3.44G [00:12<00:07, 194MB/s]
#
#
# diffusion_pytorch_model.safetensors:  56% 1.94G/3.44G [00:12<00:07, 192MB/s]
#
#
# diffusion_pytorch_model.safetensors:  57% 1.96G/3.44G [00:12<00:07, 197MB/s]
#
#
# diffusion_pytorch_model.safetensors:  58% 1.99G/3.44G [00:12<00:07, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  59% 2.02G/3.44G [00:13<00:06, 213MB/s]
#
#
# diffusion_pytorch_model.safetensors:  60% 2.06G/3.44G [00:13<00:07, 197MB/s]
#
#
# diffusion_pytorch_model.safetensors:  60% 2.08G/3.44G [00:13<00:06, 197MB/s]
#
#
# diffusion_pytorch_model.safetensors:  61% 2.10G/3.44G [00:13<00:06, 193MB/s]
#
#
# diffusion_pytorch_model.safetensors:  62% 2.12G/3.44G [00:13<00:07, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  63% 2.15G/3.44G [00:14<00:15, 84.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  63% 2.17G/3.44G [00:16<00:40, 31.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  64% 2.19G/3.44G [00:16<00:31, 39.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  64% 2.21G/3.44G [00:16<00:24, 50.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  65% 2.23G/3.44G [00:16<00:18, 64.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  66% 2.25G/3.44G [00:16<00:14, 80.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  66% 2.28G/3.44G [00:16<00:12, 89.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  67% 2.30G/3.44G [00:16<00:11, 100MB/s]
#
#
# diffusion_pytorch_model.safetensors:  67% 2.32G/3.44G [00:17<00:10, 108MB/s]
#
#
# diffusion_pytorch_model.safetensors:  68% 2.34G/3.44G [00:17<00:09, 117MB/s]
#
#
# diffusion_pytorch_model.safetensors:  69% 2.36G/3.44G [00:17<00:08, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:  69% 2.38G/3.44G [00:17<00:07, 141MB/s]
#
#
# diffusion_pytorch_model.safetensors:  70% 2.40G/3.44G [00:17<00:06, 152MB/s]
#
#
# diffusion_pytorch_model.safetensors:  70% 2.42G/3.44G [00:17<00:06, 159MB/s]
#
#
# diffusion_pytorch_model.safetensors:  71% 2.44G/3.44G [00:17<00:05, 169MB/s]
#
#
# diffusion_pytorch_model.safetensors:  72% 2.46G/3.44G [00:17<00:05, 167MB/s]
#
#
# diffusion_pytorch_model.safetensors:  72% 2.49G/3.44G [00:18<00:05, 170MB/s]
#
#
# diffusion_pytorch_model.safetensors:  73% 2.51G/3.44G [00:18<00:05, 173MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.53G/3.44G [00:18<00:05, 178MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.55G/3.44G [00:18<00:04, 179MB/s]
#
#
# diffusion_pytorch_model.safetensors:  75% 2.57G/3.44G [00:18<00:07, 118MB/s]
#
#
# diffusion_pytorch_model.safetensors:  75% 2.59G/3.44G [00:22<00:50, 16.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  76% 2.62G/3.44G [00:24<00:47, 17.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  77% 2.63G/3.44G [00:24<00:41, 19.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  77% 2.65G/3.44G [00:24<00:29, 26.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  78% 2.67G/3.44G [00:24<00:21, 35.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  78% 2.69G/3.44G [00:24<00:15, 47.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  79% 2.72G/3.44G [00:24<00:11, 61.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  80% 2.74G/3.44G [00:25<00:08, 78.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.44G [00:25<00:06, 104MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.44G [00:25<00:04, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [00:25<00:04, 148MB/s]
#
#
# diffusion_pytorch_model.safetensors:  83% 2.85G/3.44G [00:25<00:03, 155MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 2.88G/3.44G [00:25<00:03, 173MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 2.92G/3.44G [00:25<00:02, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 2.94G/3.44G [00:25<00:02, 190MB/s]
#
#
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.44G [00:26<00:02, 188MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 2.98G/3.44G [00:26<00:02, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 3.00G/3.44G [00:26<00:02, 184MB/s]
#
#
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.44G [00:26<00:02, 182MB/s]
#
#
# diffusion_pytorch_model.safetensors:  89% 3.05G/3.44G [00:26<00:02, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.44G [00:26<00:01, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 3.11G/3.44G [00:26<00:01, 208MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 3.15G/3.44G [00:27<00:01, 213MB/s]
#
#
# diffusion_pytorch_model.safetensors:  92% 3.18G/3.44G [00:27<00:01, 202MB/s]
#
#
# diffusion_pytorch_model.safetensors:  93% 3.20G/3.44G [00:27<00:01, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  94% 3.22G/3.44G [00:27<00:01, 175MB/s]
#
#
# diffusion_pytorch_model.safetensors:  94% 3.24G/3.44G [00:27<00:01, 175MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 3.26G/3.44G [00:27<00:01, 168MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 3.28G/3.44G [00:30<00:06, 24.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.44G [00:31<00:05, 25.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  97% 3.32G/3.44G [00:31<00:03, 32.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  97% 3.34G/3.44G [00:31<00:02, 41.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.44G [00:31<00:01, 51.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.44G [00:31<00:00, 65.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 3.41G/3.44G [00:31<00:00, 82.1MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:32<00:00, 107MB/s]
# Fetching 14 files: 100% 14/14 [00:32<00:00,  2.34s/it]
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  17% 1/6 [00:00<00:00,  7.24it/s]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'conv_out_kernel', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'addition_embed_type_num_heads', 'resnet_out_scale_factor', 'time_cond_proj_dim', 'time_embedding_type', 'upcast_attention', 'use_linear_projection', 'only_cross_attention', 'num_class_embeds', 'num_attention_heads', 'encoder_hid_dim_type', 'attention_type', 'dropout', 'dual_cross_attention', 'time_embedding_act_fn', 'cross_attention_norm', 'mid_block_only_cross_attention', 'mid_block_type', 'class_embed_type', 'resnet_time_scale_shift', 'transformer_layers_per_block', 'reverse_transformer_layers_per_block', 'addition_time_embed_dim', 'encoder_hid_dim', 'addition_embed_type', 'resnet_skip_time_act', 'conv_in_kernel', 'timestep_post_act', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  33% 2/6 [00:01<00:04,  1.13s/it]Instantiating AutoencoderKL model under default dtype torch.float16.
# {'latents_mean', 'latents_std', 'force_upcast', 'shift_factor', 'norm_num_groups', 'use_post_quant_conv', 'use_quant_conv', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  50% 3/6 [00:03<00:04,  1.42s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 6/6 [00:06<00:00,  1.01s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/30/2025 14:04:28 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100% 3/3 [01:07<00:00, 22.48s/it]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'timestep_spacing', 'dynamic_thresholding_ratio', 'variance_type', 'thresholding', 'sample_max_value', 'prediction_type', 'rescale_betas_zero_snr', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# {'latents_mean', 'latents_std', 'force_upcast', 'shift_factor', 'norm_num_groups', 'use_post_quant_conv', 'use_quant_conv', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'conv_out_kernel', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'addition_embed_type_num_heads', 'resnet_out_scale_factor', 'time_cond_proj_dim', 'time_embedding_type', 'upcast_attention', 'use_linear_projection', 'only_cross_attention', 'num_class_embeds', 'num_attention_heads', 'encoder_hid_dim_type', 'attention_type', 'dropout', 'dual_cross_attention', 'time_embedding_act_fn', 'cross_attention_norm', 'mid_block_only_cross_attention', 'mid_block_type', 'class_embed_type', 'resnet_time_scale_shift', 'transformer_layers_per_block', 'reverse_transformer_layers_per_block', 'addition_time_embed_dim', 'encoder_hid_dim', 'addition_embed_type', 'resnet_skip_time_act', 'conv_in_kernel', 'timestep_post_act', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 04/30/2025 14:05:54 - INFO - __main__ - ***** Running training *****
# 04/30/2025 14:05:54 - INFO - __main__ -   Num examples = 10
# 04/30/2025 14:05:54 - INFO - __main__ -   Num batches each epoch = 10
# 04/30/2025 14:05:54 - INFO - __main__ -   Num Epochs = 10
# 04/30/2025 14:05:54 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/30/2025 14:05:54 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/30/2025 14:05:54 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/30/2025 14:05:54 - INFO - __main__ -   Total optimization steps = 100
# Steps: 100% 100/100 [04:19<00:00,  2.56s/it, loss=0.339, lr=2e-6]
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 04/30/2025 14:10:14 - WARNING - huggingface_hub.file_download - Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
#
#
# config.json: 100% 4.56k/4.56k [00:00<00:00, 27.3MB/s]
#
# Fetching 12 files:  25% 3/12 [00:00<00:00, 14.75it/s]
#
# model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
#
# model.safetensors:   2% 21.0M/1.22G [00:00<00:07, 157MB/s]
#
# model.safetensors:   4% 52.4M/1.22G [00:00<00:04, 237MB/s]
#
# model.safetensors:   8% 94.4M/1.22G [00:00<00:04, 265MB/s]
#
# model.safetensors:  10% 126M/1.22G [00:00<00:04, 249MB/s]
#
# model.safetensors:  13% 157M/1.22G [00:00<00:04, 244MB/s]
#
# model.safetensors:  16% 189M/1.22G [00:00<00:04, 246MB/s]
#
# model.safetensors:  18% 220M/1.22G [00:00<00:04, 247MB/s]
#
# model.safetensors:  21% 252M/1.22G [00:01<00:03, 261MB/s]
#
# model.safetensors:  23% 283M/1.22G [00:01<00:03, 271MB/s]
#
# model.safetensors:  26% 315M/1.22G [00:01<00:03, 253MB/s]
#
# model.safetensors:  28% 346M/1.22G [00:01<00:03, 255MB/s]
#
# model.safetensors:  31% 377M/1.22G [00:01<00:03, 268MB/s]
#
# model.safetensors:  34% 409M/1.22G [00:01<00:03, 227MB/s]
#
# model.safetensors:  36% 440M/1.22G [00:01<00:03, 245MB/s]
#
# model.safetensors:  39% 472M/1.22G [00:01<00:02, 257MB/s]
#
# model.safetensors:  41% 503M/1.22G [00:01<00:02, 265MB/s]
#
# model.safetensors:  44% 535M/1.22G [00:02<00:02, 272MB/s]
#
# model.safetensors:  47% 566M/1.22G [00:02<00:02, 281MB/s]
#
# model.safetensors:  49% 598M/1.22G [00:02<00:02, 281MB/s]
#
# model.safetensors:  52% 629M/1.22G [00:02<00:02, 274MB/s]
#
# model.safetensors:  54% 661M/1.22G [00:02<00:02, 264MB/s]
#
# model.safetensors:  57% 692M/1.22G [00:02<00:02, 262MB/s]
#
# model.safetensors:  60% 724M/1.22G [00:02<00:01, 259MB/s]
#
# model.safetensors:  62% 755M/1.22G [00:02<00:01, 262MB/s]
#
# model.safetensors:  65% 786M/1.22G [00:03<00:01, 273MB/s]
#
# model.safetensors:  67% 818M/1.22G [00:03<00:01, 275MB/s]
#
# model.safetensors:  71% 860M/1.22G [00:03<00:01, 290MB/s]
#
# model.safetensors:  73% 891M/1.22G [00:03<00:01, 290MB/s]
#
# model.safetensors:  77% 933M/1.22G [00:03<00:00, 301MB/s]
#
# model.safetensors:  79% 965M/1.22G [00:03<00:00, 289MB/s]
#
# model.safetensors:  82% 996M/1.22G [00:03<00:00, 295MB/s]
#
# model.safetensors:  85% 1.03G/1.22G [00:03<00:00, 289MB/s]
#
# model.safetensors:  87% 1.06G/1.22G [00:03<00:00, 290MB/s]
#
# model.safetensors:  90% 1.09G/1.22G [00:04<00:00, 288MB/s]
#
# model.safetensors:  92% 1.12G/1.22G [00:04<00:00, 290MB/s]
#
# model.safetensors:  95% 1.15G/1.22G [00:04<00:00, 292MB/s]
#
# model.safetensors: 100% 1.22G/1.22G [00:04<00:00, 270MB/s]
#
# Fetching 12 files: 100% 12/12 [00:04<00:00,  2.49it/s]
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  4.90it/s]{'latents_mean', 'latents_std', 'force_upcast', 'shift_factor', 'norm_num_groups', 'use_post_quant_conv', 'use_quant_conv', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 15.36it/s]
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Configuration saved in ./output_model/grey_sloth_plushie/vae/config.json
# Model weights saved in ./output_model/grey_sloth_plushie/vae/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/grey_sloth_plushie/unet/config.json
# Model weights saved in ./output_model/grey_sloth_plushie/unet/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/grey_sloth_plushie/scheduler/scheduler_config.json
# Configuration saved in ./output_model/grey_sloth_plushie/model_index.json
# Steps: 100% 100/100 [05:32<00:00,  3.33s/it, loss=0.339, lr=2e-6]
# --------------------Training red_cartoon--------------------
# 2025-04-30 14:12:25.385308: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746022345.630377    6646 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746022345.698399    6646 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 14:12:26.170247: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 04/30/2025 14:12:33 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Instantiating AutoencoderKL model under default dtype torch.float16.
# {'shift_factor', 'use_post_quant_conv', 'mid_block_add_attention', 'latents_std', 'use_quant_conv', 'latents_mean', 'force_upcast', 'norm_num_groups'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  17% 1/6 [00:00<00:01,  4.33it/s]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'time_embedding_type', 'resnet_out_scale_factor', 'only_cross_attention', 'encoder_hid_dim_type', 'cross_attention_norm', 'conv_out_kernel', 'mid_block_type', 'attention_type', 'addition_time_embed_dim', 'reverse_transformer_layers_per_block', 'time_cond_proj_dim', 'num_attention_heads', 'class_embed_type', 'upcast_attention', 'timestep_post_act', 'addition_embed_type_num_heads', 'encoder_hid_dim', 'resnet_skip_time_act', 'dual_cross_attention', 'mid_block_only_cross_attention', 'class_embeddings_concat', 'use_linear_projection', 'conv_in_kernel', 'num_class_embeds', 'time_embedding_act_fn', 'time_embedding_dim', 'addition_embed_type', 'resnet_time_scale_shift', 'dropout', 'projection_class_embeddings_input_dim', 'transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  33% 2/6 [00:14<00:35,  8.76s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  50% 3/6 [00:15<00:14,  4.81s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 6/6 [00:15<00:00,  2.58s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/30/2025 14:12:49 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100% 3/3 [01:11<00:00, 23.87s/it]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'timestep_spacing', 'thresholding', 'variance_type', 'prediction_type', 'clip_sample_range', 'sample_max_value'} was not found in config. Values will be initialized to default values.
# {'shift_factor', 'use_post_quant_conv', 'mid_block_add_attention', 'latents_std', 'use_quant_conv', 'latents_mean', 'force_upcast', 'norm_num_groups'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'time_embedding_type', 'resnet_out_scale_factor', 'only_cross_attention', 'encoder_hid_dim_type', 'cross_attention_norm', 'conv_out_kernel', 'mid_block_type', 'attention_type', 'addition_time_embed_dim', 'reverse_transformer_layers_per_block', 'time_cond_proj_dim', 'num_attention_heads', 'class_embed_type', 'upcast_attention', 'timestep_post_act', 'addition_embed_type_num_heads', 'encoder_hid_dim', 'resnet_skip_time_act', 'dual_cross_attention', 'mid_block_only_cross_attention', 'class_embeddings_concat', 'use_linear_projection', 'conv_in_kernel', 'num_class_embeds', 'time_embedding_act_fn', 'time_embedding_dim', 'addition_embed_type', 'resnet_time_scale_shift', 'dropout', 'projection_class_embeddings_input_dim', 'transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 04/30/2025 14:14:10 - INFO - __main__ - ***** Running training *****
# 04/30/2025 14:14:10 - INFO - __main__ -   Num examples = 10
# 04/30/2025 14:14:10 - INFO - __main__ -   Num batches each epoch = 10
# 04/30/2025 14:14:10 - INFO - __main__ -   Num Epochs = 10
# 04/30/2025 14:14:10 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/30/2025 14:14:10 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/30/2025 14:14:10 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/30/2025 14:14:10 - INFO - __main__ -   Total optimization steps = 100
# Steps: 100% 100/100 [04:14<00:00,  2.59s/it, loss=0.111, lr=2e-6] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'shift_factor', 'use_post_quant_conv', 'mid_block_add_attention', 'latents_std', 'use_quant_conv', 'latents_mean', 'force_upcast', 'norm_num_groups'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  2.82it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  9.04it/s]
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Configuration saved in ./output_model/red_cartoon/vae/config.json
# Model weights saved in ./output_model/red_cartoon/vae/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/red_cartoon/unet/config.json
# Model weights saved in ./output_model/red_cartoon/unet/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/red_cartoon/scheduler/scheduler_config.json
# Configuration saved in ./output_model/red_cartoon/model_index.json
# Steps: 100% 100/100 [05:25<00:00,  3.26s/it, loss=0.111, lr=2e-6]
# --------------------Training pink_sunglasses--------------------
# 2025-04-30 14:20:34.600737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746022834.961197    8711 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746022835.040639    8711 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 14:20:35.792519: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 04/30/2025 14:20:46 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  17% 1/6 [00:02<00:12,  2.49s/it]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'timestep_post_act', 'use_linear_projection', 'num_attention_heads', 'time_embedding_type', 'conv_in_kernel', 'encoder_hid_dim', 'dropout', 'resnet_out_scale_factor', 'resnet_time_scale_shift', 'time_embedding_dim', 'time_cond_proj_dim', 'class_embed_type', 'attention_type', 'reverse_transformer_layers_per_block', 'dual_cross_attention', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'addition_embed_type', 'encoder_hid_dim_type', 'transformer_layers_per_block', 'addition_embed_type_num_heads', 'addition_time_embed_dim', 'conv_out_kernel', 'upcast_attention', 'resnet_skip_time_act', 'mid_block_type', 'mid_block_only_cross_attention', 'num_class_embeds', 'only_cross_attention', 'cross_attention_norm', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  33% 2/6 [00:11<00:25,  6.37s/it]Instantiating AutoencoderKL model under default dtype torch.float16.
# {'mid_block_add_attention', 'latents_mean', 'latents_std', 'norm_num_groups', 'force_upcast', 'shift_factor', 'use_post_quant_conv', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  50% 3/6 [00:12<00:11,  3.88s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 6/6 [00:12<00:00,  2.11s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/30/2025 14:20:59 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100% 3/3 [01:11<00:00, 23.86s/it]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'clip_sample_range', 'variance_type', 'rescale_betas_zero_snr', 'sample_max_value', 'prediction_type', 'dynamic_thresholding_ratio', 'timestep_spacing', 'thresholding'} was not found in config. Values will be initialized to default values.
# {'mid_block_add_attention', 'latents_mean', 'latents_std', 'norm_num_groups', 'force_upcast', 'shift_factor', 'use_post_quant_conv', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# ...
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/30/2025 14:28:58 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100% 3/3 [01:11<00:00, 23.73s/it]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'dynamic_thresholding_ratio', 'thresholding', 'variance_type', 'sample_max_value', 'rescale_betas_zero_snr', 'timestep_spacing', 'prediction_type', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# {'latents_std', 'use_quant_conv', 'force_upcast', 'norm_num_groups', 'use_post_quant_conv', 'latents_mean', 'shift_factor', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'time_embedding_dim', 'reverse_transformer_layers_per_block', 'addition_embed_type', 'mid_block_only_cross_attention', 'time_embedding_act_fn', 'cross_attention_norm', 'mid_block_type', 'use_linear_projection', 'attention_type', 'resnet_skip_time_act', 'addition_embed_type_num_heads', 'addition_time_embed_dim', 'resnet_out_scale_factor', 'dropout', 'time_embedding_type', 'num_attention_heads', 'conv_out_kernel', 'projection_class_embeddings_input_dim', 'only_cross_attention', 'class_embeddings_concat', 'upcast_attention', 'dual_cross_attention', 'encoder_hid_dim_type', 'conv_in_kernel', 'timestep_post_act', 'encoder_hid_dim', 'transformer_layers_per_block', 'num_class_embeds', 'time_cond_proj_dim', 'class_embed_type', 'resnet_time_scale_shift'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 04/30/2025 14:30:14 - INFO - __main__ - ***** Running training *****
# 04/30/2025 14:30:14 - INFO - __main__ -   Num examples = 10
# 04/30/2025 14:30:14 - INFO - __main__ -   Num batches each epoch = 10
# 04/30/2025 14:30:14 - INFO - __main__ -   Num Epochs = 10
# 04/30/2025 14:30:14 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/30/2025 14:30:14 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/30/2025 14:30:14 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/30/2025 14:30:14 - INFO - __main__ -   Total optimization steps = 100
# Steps: 100% 100/100 [04:21<00:00,  2.55s/it, loss=0.547, lr=2e-6] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'latents_std', 'use_quant_conv', 'force_upcast', 'norm_num_groups', 'use_post_quant_conv', 'latents_mean', 'shift_factor', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  2.60it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.38it/s]
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Configuration saved in ./output_model/shiny_sneaker/vae/config.json
# Model weights saved in ./output_model/shiny_sneaker/vae/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/shiny_sneaker/unet/config.json
# Model weights saved in ./output_model/shiny_sneaker/unet/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/shiny_sneaker/scheduler/scheduler_config.json
# Configuration saved in ./output_model/shiny_sneaker/model_index.json
# Steps: 100% 100/100 [05:21<00:00,  3.22s/it, loss=0.547, lr=2e-6]
# --------------------Training backpack_dog--------------------
# 2025-04-30 14:36:35.662965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746023795.882299   12702 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746023795.937311   12702 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 14:36:36.423783: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 04/30/2025 14:36:43 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Instantiating AutoencoderKL model under default dtype torch.float16.
# {'mid_block_add_attention', 'norm_num_groups', 'use_post_quant_conv', 'latents_mean', 'use_quant_conv', 'force_upcast', 'shift_factor', 'latents_std'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  17% 1/6 [00:00<00:03,  1.47it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...:  67% 4/6 [00:00<00:00,  5.97it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
# Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'mid_block_only_cross_attention', 'class_embed_type', 'encoder_hid_dim_type', 'addition_embed_type_num_heads', 'cross_attention_norm', 'attention_type', 'num_attention_heads', 'mid_block_type', 'projection_class_embeddings_input_dim', 'time_embedding_dim', 'num_class_embeds', 'dropout', 'resnet_time_scale_shift', 'class_embeddings_concat', 'use_linear_projection', 'dual_cross_attention', 'conv_out_kernel', 'addition_time_embed_dim', 'only_cross_attention', 'transformer_layers_per_block', 'upcast_attention', 'time_embedding_type', 'addition_embed_type', 'resnet_skip_time_act', 'encoder_hid_dim', 'timestep_post_act', 'conv_in_kernel', 'reverse_transformer_layers_per_block', 'resnet_out_scale_factor', 'time_cond_proj_dim', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 6/6 [00:13<00:00,  2.18s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/30/2025 14:36:56 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100% 3/3 [01:11<00:00, 23.86s/it]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type', 'timestep_spacing', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'sample_max_value', 'thresholding', 'prediction_type', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# {'mid_block_add_attention', 'norm_num_groups', 'use_post_quant_conv', 'latents_mean', 'use_quant_conv', 'force_upcast', 'shift_factor', 'latents_std'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'mid_block_only_cross_attention', 'class_embed_type', 'encoder_hid_dim_type', 'addition_embed_type_num_heads', 'cross_attention_norm', 'attention_type', 'num_attention_heads', 'mid_block_type', 'projection_class_embeddings_input_dim', 'time_embedding_dim', 'num_class_embeds', 'dropout', 'resnet_time_scale_shift', 'class_embeddings_concat', 'use_linear_projection', 'dual_cross_attention', 'conv_out_kernel', 'addition_time_embed_dim', 'only_cross_attention', 'transformer_layers_per_block', 'upcast_attention', 'time_embedding_type', 'addition_embed_type', 'resnet_skip_time_act', 'encoder_hid_dim', 'timestep_post_act', 'conv_in_kernel', 'reverse_transformer_layers_per_block', 'resnet_out_scale_factor', 'time_cond_proj_dim', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 04/30/2025 14:38:13 - INFO - __main__ - ***** Running training *****
# 04/30/2025 14:38:13 - INFO - __main__ -   Num examples = 10
# 04/30/2025 14:38:13 - INFO - __main__ -   Num batches each epoch = 10
# 04/30/2025 14:38:13 - INFO - __main__ -   Num Epochs = 10
# 04/30/2025 14:38:13 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/30/2025 14:38:13 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/30/2025 14:38:13 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/30/2025 14:38:13 - INFO - __main__ -   Total optimization steps = 100
# Steps: 100% 100/100 [04:19<00:00,  2.54s/it, loss=0.16, lr=2e-6] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'mid_block_add_attention', 'norm_num_groups', 'use_post_quant_conv', 'latents_mean', 'use_quant_conv', 'force_upcast', 'shift_factor', 'latents_std'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.30it/s]
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Configuration saved in ./output_model/backpack_dog/vae/config.json
# Model weights saved in ./output_model/backpack_dog/vae/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/backpack_dog/unet/config.json
# Model weights saved in ./output_model/backpack_dog/unet/diffusion_pytorch_model.safetensors
# Configuration saved in ./output_model/backpack_dog/scheduler/scheduler_config.json
# Configuration saved in ./output_model/backpack_dog/model_index.json
# Steps: 100% 100/100 [05:07<00:00,  3.07s/it, loss=0.16, lr=2e-6]

# %%
def generate_images_for_class(prompt, pipe ,output_dir ,num_images = 5):
    """
    Generate images using Stable Diffusion for a given prompt and save them.
    """
    # !rm -rf "{output_dir}"
    # !mkdir -p "{output_dir}"
    generated_images = []
    for i in range(num_images):
        image = pipe(prompt).images[0].resize((256, 256))
        image_path = os.path.join(output_dir, f"generated_{i}.png")
        image.save(image_path)
        generated_images.append(image)
    return generated_images

# %%
#@title Inference
from diffusers import StableDiffusionPipeline
import torch
# %cd '{DRIVE_PATH}'

# !rm -rf generated_images
# !mkdir -p generated_images

for dir_name in dirs:
  model_id = f"./output_model/{dir_name}"
  pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16).to("cuda")
  class_name = re.sub(r'[0-9]','',dir_name).replace("_"," ")
  prompt = f"a photo of sks {class_name}"
  out_dir = f"./generated_images/{dir_name}"
  generated_images = generate_images_for_class(prompt,pipe,out_dir,num_images=5)

# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# /content/drive/MyDrive/dreambooth

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install pytorch_fid
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-dr1evccg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-dr1evccg
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (0.21.0+cu124)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=88e43e446d3a13247342ff7499e66bbb2165999a4d8ea60d12867ca55af0ebbc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1hu0ajyj/wheels/3f/7c/a4/9b490845988bf7a4db33674d52f709f088f64392063872eb9a
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0
# Collecting pytorch_fid
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pytorch_fid) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pytorch_fid) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pytorch_fid) (1.15.2)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pytorch_fid) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from pytorch_fid) (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1->pytorch_fid) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.1->pytorch_fid) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.1->pytorch_fid) (3.0.2)
# Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pytorch_fid
# Successfully installed pytorch_fid-0.3.0

# %%
from PIL import Image
def read_all_images(image_dir):
  images = []
  for root, dirs, files in os.walk(image_dir):
    for file in files:
      images.append(Image.open(os.path.join(root, file)))
  return images

# %%
import clip
import numpy as np

def compute_clip_similarity(images, prompt, clip_model, clip_preprocess, device="cuda"):
    """Compute average CLIP cosine similarity between generated images and a prompt."""
    text_tokens = clip.tokenize([prompt]).to(device)
    with torch.no_grad():
      text_features = clip_model.encode_text(text_tokens)
    text_features = text_features / text_features.norm(dim=-1, keepdim=True)
    similarities = []
    for img in images:
        image_input = clip_preprocess(img).unsqueeze(0).to(device)
        with torch.no_grad():
            image_features = clip_model.encode_image(image_input)
        image_features = image_features / image_features.norm(dim=-1, keepdim=True)
        sim = (image_features @ text_features.T).item()
        similarities.append(sim)
    return np.mean(similarities)

# %%
#@title CLIP score
# %cd '{DRIVE_PATH}'
import torch
import os
import re

dirs = ["grey_sloth_plushie","red_cartoon","pink_sunglasses","shiny_sneaker","backpack_dog"]
for dir_name in dirs:
  out_dir = f"./generated_images/{dir_name}"
  generated_images = read_all_images(out_dir)
  class_name = re.sub(r'[0-9]','',dir_name).replace("_"," ")
  prompt = f"a photo of sks {class_name}"
  clip_model, clip_preprocess = clip.load("ViT-L/14", device="cuda")
  clip_score = compute_clip_similarity(generated_images, prompt, clip_model, clip_preprocess)
  print(f"CLIP SCORE for {dir_name}: {clip_score}")
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# 100%|████████████████████████████████████████| 890M/890M [00:07<00:00, 118MiB/s]
# CLIP SCORE for grey_sloth_plushie: 0.323681640625
# CLIP SCORE for red_cartoon: 0.2294189453125
# CLIP SCORE for pink_sunglasses: 0.284912109375
# CLIP SCORE for shiny_sneaker: 0.27568359375
# CLIP SCORE for backpack_dog: 0.2849609375
# /content/drive/MyDrive/dreambooth

# %%
def resize_images_in_folder(folder_path, target_size=(299, 299)):
    """
    Resizes all image files in the folder (and subfolders) to the target size.
    """
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('png', 'jpg', 'jpeg')):
                file_path = os.path.join(root, file)
                try:
                    with Image.open(file_path) as img:
                        # Resize and overwrite the image
                        img_resized = img.resize(target_size, Image.LANCZOS)
                        img_resized.save(file_path)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    print(f"Resized all images in {folder_path} to {target_size}")

# %%
#@title FID
# %cd '{DRIVE_PATH}'
from pytorch_fid import fid_score

for dir_name in dirs:
  out_dir = f"./generated_images/{dir_name}"
  in_dir = f"./training_images/dataset/{dir_name}"
  resize_images_in_folder(in_dir,(256,256))
  fid_value = fid_score.calculate_fid_given_paths(
            [in_dir, out_dir],
            batch_size=5, device="cuda", dims=2048
        )
  print(f"FID SCORE for {dir_name}: {fid_value}")
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# Resized all images in ./training_images/dataset/grey_sloth_plushie to (256, 256)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:00<00:00, 270MB/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# FID SCORE for grey_sloth_plushie: 182.64000282929507
# Resized all images in ./training_images/dataset/red_cartoon to (256, 256)
# Warning: batch size is bigger than the data size. Setting batch size to data size
# 100%|██████████| 1/1 [00:00<00:00,  3.65it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# FID SCORE for red_cartoon: 399.5524070425107
# Resized all images in ./training_images/dataset/pink_sunglasses to (256, 256)
# 100%|██████████| 2/2 [00:00<00:00,  5.48it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# FID SCORE for pink_sunglasses: 257.8247929473395
# Resized all images in ./training_images/dataset/shiny_sneaker to (256, 256)
# 100%|██████████| 2/2 [00:00<00:00,  7.87it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# FID SCORE for shiny_sneaker: 235.2605678377939
# Resized all images in ./training_images/dataset/backpack_dog to (256, 256)
# 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# FID SCORE for backpack_dog: 378.48594936601324
# /content/drive/MyDrive/dreambooth

# %%
# %cd '{DRIVE_PATH}'
import matplotlib.pyplot as plt
dirs = ["grey_sloth_plushie","red_cartoon","pink_sunglasses","shiny_sneaker","backpack_dog"]
rows = 5
cols = 5
fig, axs = plt.subplots(rows, cols, figsize=(cols*3, rows*3))
for i,dir_name in enumerate(dirs):
  images = read_all_images(f"./generated_images/{dir_name}")
  axs[i][0].set_title(dir_name)
  for j,image in enumerate(images):
    ax = axs[i][j]
    ax.axis('off')
    ax.imshow(image)
plt.savefig('./graph/images.png')
plt.show()
# %cd '{DRIVE_PATH}'
# Out:
# /content/drive/MyDrive/dreambooth
# /content/drive/MyDrive/dreambooth
